# %% [markdown]
# # NICTO Super-Training on Colab
# Trains 4 base models × 5 adapters (Kyros, Omega, Main, X, Universal).
# **Runtime required**: GPU (T4/V100/A100)
# **Estimated time**: ~20 hours for all 20 trainings

# %%
# Clone NICTO repo
# !git clone https://github.com/stephenwahogo0-arch/NICTO.git
# %cd NICTO

# %%
# Run the full training pipeline
# !python scripts/colab_train_all.py

# %% [markdown]
# ## Manual Steps (if pipeline needs restart)
# ```python
# # Step 1: Install
# !pip install -q unsloth unsloth_zoo transformers datasets trl accelerate
#
# # Step 2: Download data
# !wget -q https://raw.githubusercontent.com/stephenwahogo0-arch/NICTO/main/kaggle_data/universal_chatml.jsonl
#
# # Step 3: Train specific adapter
# from scripts.colab_train_all import train_adapter
# train_adapter(
#     base_model_id='Qwen/Qwen2.5-7B-Instruct',
#     model_name='qwen25',
#     adapter_name='universal',
#     data_path='universal_chatml.jsonl',
#     output_dir='/content/drive/MyDrive/nicto_training/qwen25',
#     max_seq=32768
# )
# ```
