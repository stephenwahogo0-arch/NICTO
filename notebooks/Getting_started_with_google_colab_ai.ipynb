# %% [markdown]
# <a href="https://colab.research.google.com/github/stephenwahogo0-arch/NICTO/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colab is making it easier than ever to integrate powerful Generative AI capabilities into your projects. We are launching public preview for a simple and intuitive Python library (google.colab.ai) to access state-of-the-art language models directly within Colab environments. All users have free access to most popular LLMs, while paid users have access to a wider selection of models. This means users can spend less time on configuration and set up and more time bringing their ideas to life. With just a few lines of code, you can now perform a variety of tasks:
# - Generate text
# - Translate languages
# - Write creative content
# - Categorize text
#
# Happy Coding!
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb)

# %%
# @title List available models
from google.colab import ai

ai.list_models()
# Out:
# ['google/gemini-2.0-flash',
#  'google/gemini-2.0-flash-lite',
#  'google/gemini-2.5-flash',
#  'google/gemini-2.5-flash-lite',
#  'google/gemini-2.5-pro',
#  'google/gemma-3-12b',
#  'google/gemma-3-1b',
#  'google/gemma-3-27b',
#  'google/gemma-3-4b']

# %%
helo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3648/2933871403.py in <cell line: 0>()
# ----> 1 helo
#
# NameError: name 'helo' is not defined

# %% [markdown]
# Choosing a Model
# The model names give you a hint about their capabilities and intended use:
#
# Pro: These are the most capable models, ideal for complex reasoning, creative tasks, and detailed analysis.
#
# Flash: These models are optimized for high speed and efficiency, making them great for summarization, chat applications, and tasks requiring rapid responses.
#
# Gemma: These are lightweight, open-weight models suitable for a variety of text generation tasks and are great for experimentation.

# %%
# @title Simple batch generation example
# Only text-to-text input/output is supported
from google.colab import ai

response = ai.generate_text("What is the capital of France?")
print(response)
# Out:
# The capital of France is **Paris**.

# %%
# @title Choose a different model
from google.colab import ai

response = ai.generate_text("What is the capital of England", model_name='google/gemini-2.0-flash-lite')
print(response)
# Out:
# The capital of England is **London**.

# %% [markdown]
# For longer text generations, you can stream the response. This displays the output token by token as it's generated, rather than waiting for the entire response to complete. This provides a more interactive and responsive experience. To enable this, simply set stream=True.

# %%
# @title Simple streaming example
from google.colab import ai

stream = ai.generate_text("Tell me a short story.", stream=True)
for text in stream:
  print(text, end='')
# Out:
# The lighthouse keeper, Silas, was a man of routine. Every night, for fifty years, he'd lit the lamp, a beacon against the treacherous rocks that gnawed at the coastline. The sea was his companion, his enemy, and his only confidante. He knew its moods better than his own.
#
# One stormy night, the wind howled like a banshee. The waves crashed against the tower, shaking it to its core. Silas, clinging to the railing, felt a fear he hadn't experienced in decades. This wasn't just a storm; this was a monster.
#
# Suddenly, a small, wooden boat, tossed about like a toy, appeared in the raging sea. He squinted, his heart leaping into his throat. A child. Alone.
#
# Ignoring the raging tempest, Silas raced down the winding stairs, his old bones protesting with every step. He launched his small rescue boat, a fragile craft against the fury of the storm.
#
# Fighting the waves, he reached the child. A girl, no older than seven, clung to the wreckage, her face white with terror. With a strength born of desperation, Silas pulled her aboard.
#
# The journey back was a blur of wind, spray, and fear. The lighthouse seemed miles away, a distant pinprick of hope. But Silas held on, whispering words of comfort to the shivering child.
#
# Finally, they reached the safety of the tower. He wrapped her in blankets, fed her warm soup, and listened to her tale of a capsized fishing boat and a lost father.
#
# As the storm raged outside, the little girl slept, curled up in Silas's worn armchair. Looking at her, a profound shift occurred within him. For fifty years, he’d only kept the light burning. Now, he understood that the light wasn't just a warning. It was a hope, a guiding star. And he, Silas, was more than just a keeper of the light. He was a keeper of hope.
#
# The storm eventually subsided. The girl was reunited with her father, miraculously rescued from a nearby island. Silas, watching them embrace, felt a warmth he hadn't known he was missing. The sea remained, his companion and his enemy. But now, it was also a reminder of the girl he'd saved, and the profound understanding that even in the darkest storms, a single act of kindness could illuminate the world. And that, he knew, was a light worth keeping.

# %%
#@title Text formatting setup
#code is not necessary for colab.ai, but is useful in fomatting text chunks
import sys

class LineWrapper:
    def __init__(self, max_length=80):
        self.max_length = max_length
        self.current_line_length = 0

    def print(self, text_chunk):
        i = 0
        n = len(text_chunk)
        while i < n:
            start_index = i
            while i < n and text_chunk[i] not in ' \n': # Find end of word
                i += 1
            current_word = text_chunk[start_index:i]

            delimiter = ""
            if i < n: # If not end of chunk, we found a delimiter
                delimiter = text_chunk[i]
                i += 1 # Consume delimiter

            if current_word:
                needs_leading_space = (self.current_line_length > 0)

                # Case 1: Word itself is too long for a line (must be broken)
                if len(current_word) > self.max_length:
                    if needs_leading_space: # Newline if current line has content
                        sys.stdout.write('\n')
                        self.current_line_length = 0
                    for char_val in current_word: # Break the long word
                        if self.current_line_length >= self.max_length:
                            sys.stdout.write('\n')
                            self.current_line_length = 0
                        sys.stdout.write(char_val)
                        self.current_line_length += 1
                # Case 2: Word doesn't fit on current line (print on new line)
                elif self.current_line_length + (1 if needs_leading_space else 0) + len(current_word) > self.max_length:
                    sys.stdout.write('\n')
                    sys.stdout.write(current_word)
                    self.current_line_length = len(current_word)
                # Case 3: Word fits on current line
                else:
                    if needs_leading_space:
                        # Define punctuation that should not have a leading space
                        # when they form an entire "word" (token) following another word.
                        no_leading_space_punctuation = {
                            ",", ".", ";", ":", "!", "?",        # Standard sentence punctuation
                            ")", "]", "}",                     # Closing brackets
                            "'s", "'S", "'re", "'RE", "'ve", "'VE", # Common contractions
                            "'m", "'M", "'ll", "'LL", "'d", "'D",
                            "n't", "N'T",
                            "...", "…"                          # Ellipses
                        }
                        if current_word not in no_leading_space_punctuation:
                            sys.stdout.write(' ')
                            self.current_line_length += 1
                    sys.stdout.write(current_word)
                    self.current_line_length += len(current_word)

            if delimiter == '\n':
                sys.stdout.write('\n')
                self.current_line_length = 0
            elif delimiter == ' ':
                # If line is full and a space delimiter arrives, it implies a wrap.
                if self.current_line_length >= self.max_length:
                    sys.stdout.write('\n')
                    self.current_line_length = 0

        sys.stdout.flush()

# %%
# @title Formatted streaming example
from google.colab import ai

wrapper = LineWrapper()
for chunk in ai.generate_text('Give me a long winded description about the evolution of the Roman Empire.', model_name='google/gemini-2.0-flash', stream=True):
  wrapper.print(chunk)
# Out:
# Alright, settle in, because the Roman Empire’s evolution wasn't a tidy, linear
# process. It was a centuries-long, tumultuous transformation, marked by
# breathtaking innovation, brutal power struggles, and a slow, creeping societal
# decay. We're talking about a journey from a humble city-state in the Italian
# peninsula to a sprawling, multifaceted empire that left an indelible mark on
# law, language, architecture, governance, and even our very understanding of the
# world.
#
# It all began, as legend would have it, with Romulus and Remus, twin brothers
# raised by a she-wolf, who founded the city of Rome in 753 BCE. Now, that’s just
# a legend, but it serves to highlight the foundational spirit of Rome: ambition,
# strength, and a certain ruthlessness. Initially, Rome was ruled by a monarchy, a
# system eventually deemed unsatisfactory by the powerful patrician class. This
# led to the **Roman Republic**, established around 509 BCE, a watershed moment
# that would define the early character of Rome.
#
# The Republic was a complex system of checks and balances designed to prevent any
# one individual from gaining absolute power. It involved a Senate, composed of
# elder statesmen primarily drawn from the patrician class, who advised and
# controlled finances; elected officials, such as Cons uls (two elected heads of
# state who served one-year terms), Praetors (judges), and Quaestors (financial
# administrators); and popular assemblies where citizens could theoretically
# participate in governance.
#
# But the Republic wasn't a democracy in the modern sense. Power was largely
# concentrated in the hands of the wealthy aristocratic families, and while
# plebeians (the common citizens) eventually gained some representation through
# tribunes who could veto acts of the Senate, the system remained inherently
# biased.
#
# This period of the Republic was one of relentless expansion. Through a series of
# shrewd alliances and brutal wars, Rome gradually conquered its neighbors,
# including the Etruscans, the Samnites, and various other Italian tribes. These
# victories were crucial because they allowed Rome to control the Italian
# peninsula, providing it with manpower, resources, and a strategic advantage.
#
# The **Punic Wars** against Carthage, a powerful North African trading empire,
# were a defining moment. These protracted conflicts, especially the Second Punic
# War with Hannibal's legendary invasion of Italy, tested Rome's resilience to the
# absolute limit. The Roman resilience, coupled with tactical brilliance and
# strategic advantages, ultimately led to Carthage's complete destruction,
# establishing Rome as the dominant power in the Mediterranean.
#
# However, the very success of the Republic sowed the seeds of its eventual
# downfall. The influx of wealth and slaves from conquered territories created
# vast disparities in wealth. Powerful generals, enriched by conquest and
# commanding loyal armies, began to challenge the authority of the Senate.
#
# Figures like **Marius**, who revolutionized the Roman army by allowing landless
# citizens to enlist, creating a professional, loyal force, and **Sulla**, who
# marched on Rome with his army to seize power, demonstrated the fragility of the
# Republican system. This era saw a series of civil wars and political
# assassinations, further destabilizing the Republic.
#
# The **First Triumvirate**, an informal alliance between Julius Caesar, Pompey,
# and Crassus, was an attempt to stabilize the political landscape, but it
# ultimately collapsed due to ambition and rivalry. **Julius Caesar's** rise to
# power was perhaps the most dramatic turning point. He conquered Gaul, defied the
# Senate, crossed the Rubicon, and ultimately seized control of Rome as dictator
# perpet uo. His reforms, aimed at improving the lives of ordinary citizens and
# consolidating his power, were cut short by his assassination in 44 BCE.
#
# Caesar's assassination sparked another round of civil wars. The **Second
# Triumvirate**, comprised of Mark Antony, Octavian (Caesar's adopted son), and
# Lepidus, emerged to restore order. However, this alliance also disintegrated,
# leading to a power struggle between Antony and Octavian. Octavian's victory at
# the Battle of Actium in 31 BCE marked the definitive end of the Roman Republic.
#
# Octavian, now known as **Augustus **, carefully crafted a new political system.
# He avoided the title of "king" or "dictator," instead adopting the title of
# "Princeps," meaning "first citizen." He maintained the facade of the Republic,
# keeping the Senate and other Republican institutions, but in reality, he held
# absolute power. This transition from Republic to Empire was a gradual process,
# cleverly disguised by Augustus. He restructured the army, reformed the tax
# system, initiated massive building projects, and ushered in a period of relative
# peace and prosperity known as the **Pax Romana** (Roman Peace).
#
# The Julio-Claudian dynasty, which followed Augustus, saw a mixed bag of
# emperors. Tiberius was a capable administrator but reclusive, Caligula was
# notorious for his cruelty and extravagance, Claudius was an intellectual who
# expanded the Empire, and Nero was infamous for his alleged role in the Great
# Fire of Rome and his persecution of Christians.
#
# The year 69 CE, known as the ** Year of the Four Emperors**, revealed the
# instability of the imperial succession. After Nero's death, four different
# emperors claimed the throne in rapid succession, highlighting the power of the
# army to make and break emperors.
#
# The Flavian dynasty, established by Vespasian, brought stability and marked the
# beginning of the construction of the Col osseum. The Nerva-Antonine dynasty,
# often considered the "Five Good Emperors" (Nerva, Trajan, Hadrian, Antoninus
# Pius, Marcus Aurelius), saw the Roman Empire reach its greatest territorial
# extent and experience a period of unprecedented peace and prosperity.
#
# Trajan conquered Dacia (modern Romania) and expanded the Empire into
# Mesopotamia, while Hadrian focused on consolidating the Empire's borders and
# building defensive fortifications like Hadrian's Wall in Britain. Marcus
# Aurelius, a philosopher-king, faced constant warfare on the frontiers and wrote
# his famous "Meditations."
#
# The reign of Commodus, the son of Marcus Aurelius, marked a turning point. His
# erratic behavior and autocratic rule undermined the stability of the Empire and
# foreshadowed future troubles. The Severan dynasty, which followed, saw the rise
# of powerful military emperors who relied heavily on the army for support. This
# increased military influence further weakened the Senate and other civilian
# institutions.
#
# The 3rd century CE was a period of profound crisis. The **Crisis of the Third
# Century** was characterized by constant civil wars, barbarian invasions,
# economic decline, and plague. The Empire was divided into competing factions,
# and emperors rose and fell in rapid succession.
#
# Emperor Diocletian attempted to stabilize the Empire by dividing it into two
# halves, the Western Roman Empire and the Eastern Roman Empire (later known as
# the Byzantine Empire), each ruled by an Augustus and a Caesar. This tetrarchy, a
# system of four rulers, aimed to provide more effective governance and defense.
#
# Constantine I, also known as Constantine the Great, reunited the Empire and made
# Christianity the favored religion with the Edict of Milan in 313 CE. He also
# moved the capital from Rome to Byzantium, renaming it Constantinople. This shift
# reflected the growing importance of the Eastern provinces and the weakening of
# the Western Empire.
#
# Following Constantine's death, the Empire was again divided between his sons.
# The Western Roman Empire continued to decline, plagued by internal strife,
# economic problems, and constant barbarian invasions. The Eastern Roman Empire,
# with its stronger economy and more stable political system, managed to survive.
#
# The **Visigoths**, fleeing from the Huns, were allowed to settle within the
# Roman Empire, but their mistreatment by Roman officials led to rebellion. In 410
# CE, the Visigoths sacked Rome, a symbolic blow that shook the foundations of the
# Western Roman Empire.
#
# One by one, provinces of the Western Roman Empire were lost to various barbarian
# tribes, including the Vandals, the Franks, the Angles, and the Saxons. In 476
# CE, the last Western Roman Emperor, Romulus Augustulus, was deposed by the
# Germanic chieftain Odoacer, marking the traditional end of the Western Roman
# Empire.
#
# The Eastern Roman Empire, or Byzantine Empire, continued to flourish for another
# thousand years, preserving Roman traditions and culture. It would eventually
# fall to the Ottoman Turks in 1453, with the capture of Constantinople.
#
# So, the evolution of the Roman Empire was a complex and multifaceted process,
# spanning centuries and encompassing profound political, social, economic, and
# cultural transformations. From a small Republic to a vast empire, and eventually
# to a fragmented and weakened state, the Roman story is a testament to the rise
# and fall of civilizations, the enduring power of ideas, and the enduring legacy
# of one of history's most influential empires. It's a story of ambition,
# innovation, ruthlessness, and ultimately, decline – a cautionary tale and a
# source of inspiration that continues to fascinate and influence us today.

# %% [markdown]
# ## Clone the NICTO repository

# %%
get_ipython().system('git clone https://github.com/stephenwahogo0-arch/NICTO.git')
# Out:
# Cloning into 'NICTO'...
# remote: Enumerating objects: 1411, done.
# remote: Counting objects: 100% (416/416), done.
# remote: Compressing objects: 100% (381/381), done.
# remote: Total 1411 (delta 60), reused 322 (delta 14), pack-reused 995 (from 1)
# Receiving objects: 100% (1411/1411), 13.50 MiB | 16.27 MiB/s, done.
# Resolving deltas: 100% (344/344), done.

# %% [markdown]
# ## Install Dependencies and Run Tests
#
# Navigate into the cloned repository, install the necessary dependencies, and then run the test suite.

# %%
get_ipython().run_line_magic('cd', '/content/NICTO')
get_ipython().system('apt-get update && apt-get install -y xvfb python3-tk')
get_ipython().system('pip install pyautogui pyvirtualdisplay')
get_ipython().system('pip install -e packages/nikto-core')

# Setup Virtual Display and .Xauthority
import os
from pyvirtualdisplay import Display
if 'virtual_display' not in globals():
    get_ipython().system('touch /root/.Xauthority')
    virtual_display = Display(visible=0, size=(1366, 768))
    virtual_display.start()

os.environ['DISPLAY'] = ':0'
get_ipython().system('python test_nikto.py')
# Out:
# /content/NICTO
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3-tk is already the newest version (3.10.8-1~22.04).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.
# Requirement already satisfied: pyautogui in /usr/local/lib/python3.12/dist-packages (0.9.54)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.12/dist-packages (3.0)
# Requirement already satisfied: python3-Xlib in /usr/local/lib/python3.12/dist-packages (from pyautogui) (0.15)
# Requirement already satisfied: pymsgbox in /usr/local/lib/python3.12/dist-packages (from pyautogui) (2.0.1)
# Requirement already satisfied: pytweening>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from pyautogui) (1.2.0)
# Requirement already satisfied: pyscreeze>=0.1.21 in /usr/local/lib/python3.12/dist-packages (from pyautogui) (1.0.1)
# Requirement already satisfied: pygetwindow>=0.0.5 in /usr/local/lib/python3.12/dist-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in /usr/local/lib/python3.12/dist-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyrect in /usr/local/lib/python3.12/dist-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: pyperclip in /usr/local/lib/python3.12/dist-packages (from mouseinfo->pyautogui) (1.11.0)
# Obtaining file:///content/NICTO/packages/nikto-core
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: nikto-core
#   Building editable for nikto-core (pyproject.toml) ... done
#   Created wheel for nikto-core: filename=nikto_core-0.1.0-py3-none-any.whl size=1025 sha256=f0deadfdf7e1a6d73d7286d2e698780b1732ed287404c28766e0bde2a4240765
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_daqkibq/wheels/cd/d0/79/0b97c48ad7da38061b44630bb232c3fdd1e0206b605666cb26
# Successfully built nikto-core
# Installing collected packages: nikto-core
#   Attempting uninstall: nikto-core
#     Found existing installation: nikto-core 0.1.0
#     Uninstalling nikto-core-0.1.0:
#       Successfully uninstalled nikto-core-0.1.0
# Successfully installed nikto-core-0.1.0
# ============================================================
#   NIKTO COMPREHENSIVE FEATURE TEST (1000+ FEATURES)
# ============================================================
#
# === 1. MODULE IMPORTS ===
#   [FAIL] Module imports — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 2. AGENT VARIANTS ===
#   [FAIL] Variant creation — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 3. ORCHESTRATOR — NIKTO BUILDS SUB-AGENTS ===
#   [PASS] 3 sub-agents created
#   [PASS] Tickets created
#   [PASS] Tickets assigned
#   [PASS] Ticket completed
#   [PASS] Budget tracked
#   [PASS] Status running
#   [PASS] Status shows agents
#   [PASS] Status shows tickets
#
# === 4. TOOL SYSTEM ===
#   [PASS] Tools registered
#   [PASS] Tool 'read' available
#   [PASS] Tool 'write' available
#   [PASS] Tool 'bash' available
#   [PASS] Tool 'web_fetch' available
#   [PASS] Tool 'crypto_create_wallet' available
#   [PASS] Tool 'glob' available
#   [PASS] Tool 'grep' available
#
# === 5. SECURITY TOOL WRAPPERS ===
#   [PASS] Security tool: nmap_scan
#   [PASS] Security tool: nikto_webscan
#   [PASS] Security tool: sqlmap_scan
#   [PASS] Security tool: gobuster_scan
#   [PASS] Security tool: hashcat
#   [PASS] Security tool: metasploit_exec
#   [PASS] Security tool: searchsploit
#   [PASS] Security tool: amass_enum
#   [PASS] Nmap tool function callable
#
# === 6. MEMORY SYSTEM ===
#   [PASS] Memory store works
#   [PASS] Memory recall works
#   [PASS] Memory stats available
#
# === 7. LOCAL PROVIDER ===
#   [PASS] Local provider created
#   [PASS] Local provider responds
#
# === 8. SECURITY MODULES ===
#   [FAIL] Security modules — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 9. NIKTO PLUS CYBERSECURITY SPECIALIST ===
#   [FAIL] Plus features — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 10. DENU FEATURES ===
#   [FAIL] Denu features — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 11. NIKTO NIKTO FEATURES ===
#   [FAIL] Nikto Nikto features — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 12. GUI/CUA SCREEN CONTROL ===
#   [FAIL] CUA module — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 13. MCP ECOSYSTEM ===
#   [PASS] MCP server registered
#   [PASS] MCP list returns servers
#   [PASS] MCP server unregistered
#   [PASS] MCP client validates server existence
#
# === 14. CRYPTO EARNING ===
#   [FAIL] Crypto module — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 15. DAEMON & API ===
#   [FAIL] Daemon & API — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 16. SYSTEM PROMPTS (NO CONSTRAINTS) ===
#   [FAIL] System prompts — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 17. SELF-REVIEW & CODE ACCESS ===
#   [PASS] Read own code
#   [PASS] Self-review own code
#   [PASS] ReadOwnTool has name
#   [PASS] WriteOwnTool has name
#   [PASS] SelfReviewTool has name
#
# === 18. IMAGE GENERATION ===
#   [PASS] Image generation produces file
#   [PASS] Pattern generation works
#   [PASS] ImageGenerateTool has name
#   [PASS] PatternGenerateTool has name
#
# === 19. VIDEO GENERATION ===
#   [PASS] GIF generation produces file
#   [PASS] GifGenerateTool has name
#   [PASS] VideoGenerateTool has name
#
# === 20. TEXT-TO-SPEECH ===
#   [PASS] List voices runs
#   [PASS] Speech generation produces file
#   [PASS] SpeakTool has name
#   [PASS] SpeakDirectTool has name
#   [PASS] ListVoicesTool has name
#
# === 21. AUTOPILOT ENGINE ===
#   [FAIL] Autopilot module — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 22. AUTOPILOT CONTROL TOOLS ===
#   [FAIL] Autopilot control tools — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 23. UNIVERSAL DEVICE CONTROL (uDevCon) ===
#   [FAIL] Device control module — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 24. NIKTO GAME ENGINE (NGE) ===
#   [FAIL] Game engine module — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 25. SELF-EVOLUTION ENGINE ===
#   [PASS] Self-healer runs
#   [PASS] Module analyzer works
#   [PASS] EvolutionEngine created
#   [PASS] Evolution engine starts and stops
#   [PASS] Health check tool
#   [PASS] Analyze tool
#   [PASS] EvolutionHealthTool has name
#   [PASS] EvolutionAnalyzeTool has name
#
# === 26. DREAM STATE PROCESSOR ===
#   [FAIL] Dream state module — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 27. DISTRIBUTED MESH NETWORK ===
#   [FAIL] Mesh network module — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 28. PRODUCTION SKILLS ===
#   [PASS] Production skills registered: 83
#
# === 29. ADVANCED EVOLUTION — FULL MODULE IMPORTS ===
#   [FAIL] Advanced evolution imports — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 30. BIO-MEDICAL FEATURES ===
#   [FAIL] Bio-medical features — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 31. CONSCIOUSNESS FEATURES ===
#   [FAIL] Consciousness features — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 32. PHYSICS & REALITY FEATURES ===
#   [FAIL] Physics & reality features — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 33. COMMUNICATION FEATURES ===
#   [FAIL] Communication features — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 34. GLOBAL & COSMIC FEATURES ===
#   [FAIL] Global & cosmic features — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 34. NIKTO BRAIN — 18 REGION PIPELINE ===
#   [FAIL] Brain module test — No module named 'nikto.brain.lobes'
#
# === 35. BRAIN WIRED INTO AGENT ===
#   [FAIL] Brain agent integration — VoiceEngine.__init__() got an unexpected keyword argument 'data_dir'
#
# === 36. 10 ADDITIONAL BRAIN REGIONS ===
#   [FAIL] Extra regions test — No module named 'nikto.brain.regions'
#
# === 37. MULTI-BRAIN — 6 SPECIALIZED BRAINS ===
#   [FAIL] Multi-brain test — No module named 'nikto.brain.multi'
#
# === 38. SUPER-TRAINING — ALL BRAINS × ALL REGIONS ===
#   [FAIL] Brain training test — No module named 'nikto.brain.training'
#
# === 39. HYPERBRAIN WIRED INTO AGENT ===
#   [FAIL] HyperBrain agent integration — No module named 'nikto.brain.multi'
#
# === 41. BRAIN OPTIMIZER — HEBBIAN, PRUNING, PLASTICITY ===
#   [FAIL] Brain optimizer test — No module named 'nikto.brain.optimize'
#
# === 42. RESILIENCE — 365-DAY UPTIME ===
#   [FAIL] Resilience test — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 43. SELF-DIAGNOSTICS & HEALTH MONITOR ===
#   [FAIL] Diagnostics test — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 44. GAMES — PONG, SNAKE, TETRIS, PLATFORMER, RPG ===
#   [PASS] Create pong game
#   [PASS] Create snake game
#   [PASS] Create tetris game
#   [PASS] Create platformer game
#   [PASS] Create rpg game
#   [PASS] All 5 games listed
#   [PASS] Pong game created
#   [PASS] Pong tick runs
#   [PASS] Pong move paddle
#   [PASS] Pong ends with score
#   [PASS] Snake tick runs
#   [PASS] Snake tracks score
#   [PASS] Tetris tick runs
#   [PASS] Tetris move piece
#   [PASS] Platformer tick runs
#   [PASS] Platformer jump
#   [PASS] RPG explore room
#   [PASS] RPG descend floor
#   [PASS] RPG floor increased
#   [PASS] RPGCharacter takes damage
#   [PASS] RPGCharacter heals
#   [PASS] RPGCharacter gains XP
#   [PASS] All games cleaned up
#   [PASS] ALL 5 GAMES PLAYABLE — PONG, SNAKE, TETRIS, PLATFORMER, RPG
#
# === 45. NEW AGENT FEATURES WIRED ===
#   [FAIL] New agent features test — No module named 'nikto.brain.optimize'
#
# === 46. EXTENDED SKILLS COUNT ===
#   [PASS] Skills registered: 83
#   [PASS] Resilience skill present
#   [PASS] Games skill present
#   [PASS] Brain optimize skill present
#   [PASS] Diagnostics skill present
#   [PASS] Multi brain skill present
#   [PASS] Self diagnostics skill present
#   [PASS] EXTENDED SKILLS — 87 PRODUCTION SKILLS ACTIVE
#
# === 47. BREAKTHROUGH FEATURES ===
#   [FAIL] Breakthrough features — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === SELF-REPAIR ENGINE ===
#   [FAIL] Self-repair engine — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === CODE GENERATION ENGINE ===
#   [FAIL] Code generator — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === CONTINUOUS IMPROVEMENT LOOP ===
#   [FAIL] Continuous improvement — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === HEADLESS AVATAR SYSTEM ===
#   [FAIL] Headless avatar — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 48. SOURCING ENGINE — CITATION TRACKING ===
#   [PASS] SourcingEngine created
#   [PASS] Engine has citations
#   [PASS] Engine has claims
#   [PASS] add_web_source returns Citation
#   [PASS] Citation has URL
#   [PASS] Citation has title
#   [PASS] Citation has source_type web
#   [PASS] Citation id not empty
#   [PASS] Citation to_dict works
#   [PASS] Citation to_markdown works
#   [PASS] Citation to_footnote works
#   [PASS] add_knowledge_base_source works
#   [PASS] add_academic_source works
#   [PASS] create_sourced_claim returns SourcedClaim
#   [PASS] Claim has 2 citations
#   [PASS] Claim confidence 0.95
#   [PASS] Claim to_dict works
#   [PASS] Claim to_markdown_with_citations
#   [PASS] Session summary has total_citations
#   [PASS] Session summary has total_claims
#   [PASS] citations_by_type has web
#   [PASS] average_confidence > 0
#   [PASS] format_response_with_sources adds section
#   [PASS] formatted contains citation text
#   [PASS] clear_session resets citations
#   [PASS] clear_session resets claims
#   [PASS] Empty engine avg confidence 0
#   [PASS] Empty engine citations_by_type empty
#   [PASS] Minimal citation to_markdown
#   [PASS] ALL SOURCING ENGINE FEATURES OPERATIONAL
#
# === 49. VOICE ENGINE — TTS & PROFILES ===
#   [FAIL] Voice engine test failed — VoiceEngine.__init__() got an unexpected keyword argument 'data_dir'
#
# === 50. EVOLUTION PROTOCOL — XP & LEVEL SYSTEM ===
#   [PASS] EvolutionProtocol created
#   [FAIL] Evolution protocol test failed — 'EvolutionProtocol' object has no attribute 'level'
#
# === 51. MASTERCLASS TRAINER — SURPASS COMPETITORS ===
#   [PASS] MasterclassTrainer created
#   [FAIL] Masterclass trainer test failed — 'MasterclassTrainer' object has no attribute 'get_competitor_scores'
#
# === 52. INFINITE CONTEXT ENGINE — MILLION-WORD PROCESSING ===
#   [PASS] InfiniteContextEngine created
#   [FAIL] Infinite context test failed — 'InfiniteContextEngine' object has no attribute 'total_processed'
#
# === 53. HOTKEY MANAGER — KEYBOARD SHORTCUTS ===
#   [FAIL] Hotkey manager test failed — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 54. AGENT NEW ENGINE ATTRIBUTES ===
#   [FAIL] Agent new engines attributes test failed — 1 validation error for NiktoConfig
# model
#   Input should be a valid dictionary or instance of ModelConfig [type=model_type, input_value='local-test', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/model_type
#
# === 55. ANIMATIONS & EXPRESSIONS EXTENDED COVERAGE ===
#   [FAIL] Animation expressions extended test failed — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 56. AVATAR RENDERER — HOLOGRAM & HUD ===
#   [FAIL] Avatar renderer extended test failed — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 57. AVATAR PERSONALIZATION ===
#   [FAIL] Avatar personalization test failed — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 58. EAGLE EYE — EXTENDED TRUTH VERIFICATION ===
#   [FAIL] Eagle Eye extended test failed — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 59. REGISTRATION & SAFETY — EXTENDED COVERAGE ===
#   [FAIL] Registration safety extended test failed — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 60. CONFIG EDGE CASES & BOUNDARY TESTS ===
#   [FAIL] Config edge cases test failed — cannot import name 'AgentConfig' from 'nikto.config.settings' (/content/NICTO/packages/nikto-core/src/nikto/config/settings.py)
#
# === 61. API ENDPOINTS — SOURCING, VOICE, EVOLUTION ===
#   [FAIL] API endpoints test failed — ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# === 62. CROSS-ENGINE INTEGRATION TESTS ===
#   [FAIL] Integration cross engine test failed — 1 validation error for NiktoConfig
# model
#   Input should be a valid dictionary or instance of ModelConfig [type=model_type, input_value='local-test', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/model_type
#
# === 63. EDGE CASES & BOUNDARY TESTS ===
#   [PASS] SourcingEngine with empty data_dir
#   [PASS] Empty URL/title accepted
#   [PASS] 10 bulk citations
#   [FAIL] Edge cases boundary test failed — VoiceEngine.__init__() got an unexpected keyword argument 'data_dir'
#
# === 64. ULTIMATE FEATURE COUNT ===
#   [FAIL] TOTAL TESTS EXECUTED: 180 —
#   [FAIL] TOTAL PASSED: 128 —
#   [FAIL] ALL TESTS PASS (0 FAILURES) —
#
# ============================================================
#   RESULTS: 128/183 passed, 55/183 failed
# ============================================================

# %% [markdown]
# ## Start NIKTO
#
# This command will start NIKTO. You might need to add specific arguments depending on your use case (e.g., target URL for scanning).

# %%
get_ipython().system('python -m nikto # Add your desired arguments here, e.g., -h example.com')
# Out:
# mss not installed; using pyautogui for screenshots
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 148, in _get_module_details
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/content/NICTO/packages/nikto-core/src/nikto/__init__.py", line 19, in <module>
#     from nikto.cua.screen import ScreenController
#   File "/content/NICTO/packages/nikto-core/src/nikto/cua/__init__.py", line 4, in <module>
#     from nikto.cua.input import InputController, type_text, press_key, click_at, move_mouse, scroll, drag
#   File "/content/NICTO/packages/nikto-core/src/nikto/cua/input.py", line 4, in <module>
#     import pyautogui
# ModuleNotFoundError: No module named 'pyautogui'

# %% [markdown]
# ## Comprehensive Resource Testing
# Checking module imports and testing the headless avatar engine.

# %%
import os
from pyvirtualdisplay import Display
if 'virtual_display' not in globals():
    get_ipython().system('touch /root/.Xauthority')
    virtual_display = Display(visible=0, size=(1366, 768))
    virtual_display.start()

os.environ['DISPLAY'] = ':0'
get_ipython().system('python -c "from nikto import *; print(\'NIKTO AI System loaded successfully\')"')
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/Xlib/xauth.py", line 43, in __init__
#     raw = open(filename, 'rb').read()
#           ^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/content/NICTO/packages/nikto-core/src/nikto/__init__.py", line 19, in <module>
#     from nikto.cua.screen import ScreenController
#   File "/content/NICTO/packages/nikto-core/src/nikto/cua/__init__.py", line 3, in <module>
#     from nikto.cua.screen import ScreenController, screenshot, list_screens
#   File "/content/NICTO/packages/nikto-core/src/nikto/cua/screen.py", line 11, in <module>
#     import pyautogui
#   File "/usr/local/lib/python3.12/dist-packages/pyautogui/__init__.py", line 246, in <module>
#     import mouseinfo
#   File "/usr/local/lib/python3.12/dist-packages/mouseinfo/__init__.py", line 223, in <module>
#     _display = Display(os.environ['DISPLAY'])
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/Xlib/display.py", line 80, in __init__
#     self.display = _BaseDisplay(display)
#                    ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/Xlib/display.py", line 62, in __init__
#     display.Display.__init__(*(self, ) + args, **keys)
#   File "/usr/local/lib/python3.12/dist-packages/Xlib/protocol/display.py", line 60, in __init__
#     auth_name, auth_data = connect.get_auth(self.socket,
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/Xlib/support/connect.py", line 91, in get_auth
#     return mod.get_auth(sock, dname, host, dno)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/Xlib/support/unix_connect.py", line 103, in new_get_auth
#     au = xauth.Xauthority()
#          ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/Xlib/xauth.py", line 45, in __init__
#     raise error.XauthError('~/.Xauthority: %s' % err)
# Xlib.error.XauthError: ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'

# %%
import os
from pyvirtualdisplay import Display
if 'virtual_display' not in globals():
    get_ipython().system('touch /root/.Xauthority')
    virtual_display = Display(visible=0, size=(1366, 768))
    virtual_display.start()

os.environ['DISPLAY'] = ':0'
# Test headless avatar (graphical mode)
get_ipython().system('python -c "\nfrom nikto.avatar.engine import AvatarEngine\nae = AvatarEngine()\nprint(\'Avatar engine ready\')\nprint(\'Animations:\', [a.value for a in ae.anim_player.current_anim.__class__])\n"')
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/Xlib/xauth.py", line 43, in __init__
#     raw = open(filename, 'rb').read()
#           ^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/root/.Xauthority'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<string>", line 2, in <module>
#   File "/content/NICTO/packages/nikto-core/src/nikto/__init__.py", line 19, in <module>
#     from nikto.cua.screen import ScreenController
#   File "/content/NICTO/packages/nikto-core/src/nikto/cua/__init__.py", line 3, in <module>
#     from nikto.cua.screen import ScreenController, screenshot, list_screens
#   File "/content/NICTO/packages/nikto-core/src/nikto/cua/screen.py", line 11, in <module>
#     import pyautogui
#   File "/usr/local/lib/python3.12/dist-packages/pyautogui/__init__.py", line 246, in <module>
#     import mouseinfo
#   File "/usr/local/lib/python3.12/dist-packages/mouseinfo/__init__.py", line 223, in <module>
#     _display = Display(os.environ['DISPLAY'])
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/Xlib/display.py", line 80, in __init__
#     self.display = _BaseDisplay(display)
#                    ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/Xlib/display.py", line 62, in __init__
#     display.Display.__init__(*(self, ) + args, **keys)
#   File "/usr/local/lib/python3.12/dist-packages/Xlib/protocol/display.py", line 60, in __init__
#     auth_name, auth_data = connect.get_auth(self.socket,
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/Xlib/support/connect.py", line 91, in get_auth
#     return mod.get_auth(sock, dname, host, dno)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/Xlib/support/unix_connect.py", line 103, in new_get_auth
#     au = xauth.Xauthority()
#          ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/Xlib/xauth.py", line 45, in __init__
#     raise error.XauthError('~/.Xauthority: %s' % err)
# Xlib.error.XauthError: ~/.Xauthority: [Errno 2] No such file or directory: '/root/.Xauthority'
